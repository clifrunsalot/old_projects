# %%
import pandas as pd

# %%
data = pd.read_csv('cars.csv')

# %%
data.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km) RATING  (km)  TIME (h)
# ...

# %%
data.tail()
# Out:
#     YEAR   Make                   Model            Size  (kW) Unnamed: 5 TYPE  \
# 48  2016  TESLA   MODEL S 90D (Refresh)       FULL-SIZE   386         A1    B
# 49  2016  TESLA       MODEL S P85D/P90D       FULL-SIZE   568         A1    B
# 50  2016  TESLA  MODEL S P90D (Refresh)       FULL-SIZE   568         A1    B
# 51  2016  TESLA             MODEL X 90D  SUV - STANDARD   386         A1    B
# 52  2016  TESLA            MODEL X P90D  SUV - STANDARD   568         A1    B
#
#     CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 48               20.8              19.7               20.3               2.3
# 49               23.4              21.5               22.5               2.6
# 50               22.9              21.0               22.1               2.6
# 51               23.2              22.2               22.7               2.6
# 52               23.6              23.3               23.5               2.7
#
# ...

# %%
data.shape
# Out:
# (53, 17)

# %%
data
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# ...

# %%
data.loc[21:24,['Make','Model']]
# Out:
#           Make           Model
# 21   CHEVROLET        SPARK EV
# 22        FORD  FOCUS ELECTRIC
# 23         KIA         SOUL EV
# 24  MITSUBISHI          i-MiEV

# %%
type(data.ix[21:24,['Make','Model']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(data.loc[21:24,['Make','Model']])
# Out:
# pandas.core.frame.DataFrame

# %%
data['Size'].unique()
# Out:
# array(['SUBCOMPACT', 'MID-SIZE', 'COMPACT', 'TWO-SEATER', 'FULL-SIZE',
#        'STATION WAGON - SMALL', 'SUV - STANDARD'], dtype=object)

# %%
import matplotlib as plot

# %%
subcompact = data[data['Size']=='SUBCOMPACT']

# %%
subcompact.plot

# %%
subcompact.plot(x='YEAR',y='CITY (kWh/100 km)')

# %%
subcompact.set_index('YEAR')
# Out:
#             Make     Model        Size  (kW) Unnamed: 5 TYPE  \
# YEAR
# 2012  MITSUBISHI    i-MiEV  SUBCOMPACT    49         A1    B
# 2013  MITSUBISHI    i-MiEV  SUBCOMPACT    49         A1    B
# 2014   CHEVROLET  SPARK EV  SUBCOMPACT   104         A1    B
# 2014  MITSUBISHI    i-MiEV  SUBCOMPACT    49         A1    B
# 2015         BMW        i3  SUBCOMPACT   125         A1    B
# 2015   CHEVROLET  SPARK EV  SUBCOMPACT   104         A1    B
# 2015  MITSUBISHI    i-MiEV  SUBCOMPACT    49         A1    B
# 2016         BMW        i3  SUBCOMPACT   125         A1    B
# 2016   CHEVROLET  SPARK EV  SUBCOMPACT   104         A1    B
# 2016  MITSUBISHI    i-MiEV  SUBCOMPACT    49         A1    B
#
#       CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# YEAR
# 2012               16.9              21.4               18.7
# 2013               16.9              21.4               18.7
# 2014               16.0              19.6               17.8
# ...

# %%
subcompact = data.loc[data['Size']=='SUBCOMPACT']

# %%
subcompact =  subcompact.set_index('YEAR')

# %%
subcompact.head()
# Out:
#             Make     Model        Size  (kW) Unnamed: 5 TYPE  \
# YEAR
# 2012  MITSUBISHI    i-MiEV  SUBCOMPACT    49         A1    B
# 2013  MITSUBISHI    i-MiEV  SUBCOMPACT    49         A1    B
# 2014   CHEVROLET  SPARK EV  SUBCOMPACT   104         A1    B
# 2014  MITSUBISHI    i-MiEV  SUBCOMPACT    49         A1    B
# 2015         BMW        i3  SUBCOMPACT   125         A1    B
#
#       CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  \
# YEAR
# 2012               16.9              21.4               18.7
# 2013               16.9              21.4               18.7
# 2014               16.0              19.6               17.8
# 2014               16.9              21.4               18.7
# 2015               15.2              18.8               16.8
#
#       CITY (Le/100 km)  HWY (Le/100 km)  COMB (Le/100 km)  (g/km) RATING  \
# YEAR
# 2012               1.9              2.4               2.1       0    n/a
# ...

# %%
subcompact = subcompact.loc[:,['Make','Model','CITY (kWh/100 km)','HWY (kWh/100 km)']]

# %%
subcompact.head()
# Out:
#             Make     Model  CITY (kWh/100 km)  HWY (kWh/100 km)
# YEAR
# 2012  MITSUBISHI    i-MiEV               16.9              21.4
# 2013  MITSUBISHI    i-MiEV               16.9              21.4
# 2014   CHEVROLET  SPARK EV               16.0              19.6
# 2014  MITSUBISHI    i-MiEV               16.9              21.4
# 2015         BMW        i3               15.2              18.8

# %%
subcompact.plot(y='CITY (kWh/100 km)',color='red')

# %%
import matplotlib as stat
import matplotlib.pyplot as plot

# %%
subcompact.plot(y='CITY (kWh/100 km)',color='red')

# %%
# %matplotlib inline

# %%
subcompact.plot(y='CITY (kWh/100 km)',color='red')

# %%
data.plot(x='YEAR',y='CITY (kWh/100 km)')

# %%
subcompact
# Out:
#             Make     Model  CITY (kWh/100 km)  HWY (kWh/100 km)
# YEAR
# 2012  MITSUBISHI    i-MiEV               16.9              21.4
# 2013  MITSUBISHI    i-MiEV               16.9              21.4
# 2014   CHEVROLET  SPARK EV               16.0              19.6
# 2014  MITSUBISHI    i-MiEV               16.9              21.4
# 2015         BMW        i3               15.2              18.8
# 2015   CHEVROLET  SPARK EV               16.0              19.6
# 2015  MITSUBISHI    i-MiEV               16.9              21.4
# 2016         BMW        i3               15.2              18.8
# 2016   CHEVROLET  SPARK EV               16.0              19.6
# 2016  MITSUBISHI    i-MiEV               16.9              21.4

# %%
subcompact['CITY (kWh/100 km)'].groupby(subcompact['Make']).count()
# Out:
# Make
# BMW           2
# CHEVROLET     3
# MITSUBISHI    5
# Name: CITY (kWh/100 km), dtype: int64
